# %%
import os
import csv as c
import pandas as pd
import numpy as np

# %%
Stats_data = "Resources/stats.csv"
Results_data = "Resources/results.csv"

# %%
stats_data_read = pd.read_csv(Stats_data)
results_data_read = pd.read_csv(Results_data)

# %%
stats_df = stats_data_read

# %%
stats_df.head(21)
# Out:
#                  team  wins  losses  goals  total_yel_card  total_red_card  \
# 0   Manchester United  28.0     5.0   83.0            60.0             1.0
# 1             Chelsea  24.0     3.0   64.0            62.0             4.0
# 2           Liverpool  20.0    10.0   57.0            44.0             0.0
# 3             Arsenal  19.0     8.0   63.0            59.0             3.0
# 4   Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
# 5    Bolton Wanderers  16.0    14.0   47.0            84.0             4.0
# 6             Reading  16.0    15.0   52.0            38.0             3.0
# 7    Blackburn Rovers  15.0    16.0   52.0            77.0             6.0
# 8             Everton  15.0    10.0   52.0            65.0             2.0
# 9          Portsmouth  14.0    12.0   45.0            48.0             1.0
# 10      Middlesbrough  12.0    16.0   44.0            64.0             2.0
# ...

# %%
stats_df.columns
# Out:
# Index(['team', 'wins', 'losses', 'goals', 'total_yel_card', 'total_red_card',
#        'total_scoring_att', 'ontarget_scoring_att', 'hit_woodwork',
#        'att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
#        'att_obox_goal', 'goal_fastbreak', 'total_offside', 'clean_sheet',
#        'goals_conceded', 'saves', 'outfielder_block', 'interception',
#        'total_tackle', 'last_man_tackle', 'total_clearance', 'head_clearance',
#        'own_goals', 'penalty_conceded', 'pen_goals_conceded', 'total_pass',
#        'total_through_ball', 'total_long_balls', 'backward_pass',
#        'total_cross', 'corner_taken', 'touches', 'big_chance_missed',
#        'clearance_off_line', 'dispossessed', 'penalty_save',
#        'total_high_claim', 'punches', 'season'],
#       dtype='object')

# %%
null_counts = stats_df.isnull().sum()

# %%
null_columns = null_counts[null_counts>0]

# %%
print(null_columns)
# Out:
# saves                 20
# head_clearance        20
# total_through_ball    20
# backward_pass         80
# big_chance_missed     80
# dispossessed          20
# dtype: int64

# %%
stats_df.drop(["saves", "dispossessed", "big_chance_missed", "backward_pass", "total_through_ball", "head_clearance"] , axis=1, inplace=True)

# %%
stats_df
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
new_06_07_data = stats_df.rename(columns={"team":"Team",
    "wins":"Wins",
    "losses":"Losses",
    "goals":"Goals",
    "total_yel_card":"Total Yellow Cards",
    "total_red_card": "Total Red Cards",
    "total_scoring_att":"Total Scoring Attacks",
    "ontarget_scoring_att":"Scoring On Target Attacks",                    
    "hit_woodwork":"No. Times Woodwork Hit",
    "att_hd_goal":"Headed Goals",                    
    "att_pen_goal":"Penalty Goals",                     
    "att_freekick_goal":"Freekick Goals",                     
    "att_ibox_goal":"In The Box Goals",
    "att_obox_goal": "Outside Box Goals",
    'goal_fastbreak':"Goals from Counter Attacks",   
    'total_offside':"Total Offsides",
    "clean_sheet":"Clean Sheets",
    'goals_conceded':"Goals Conceded",
    "saves":"Saves",
    "outfielder_block":"Outfielder Blocks",                    
    'interception':"Interceptions", 
    'total_tackle': "Total Tackles",
    'last_man_tackle':"Last Man Tackles",
    'total_clearance':"Total Clearances",                        
    'own_goals':"Own Goals", 
    'penalty_conceded': "Penalties Conceded",
    'pen_goals_conceded':"Penalty Goals Conceded",
    'total_pass':"Total Passes",
    'total_long_balls':"Total Long Balls",
    'total_cross':"Total Crosses", 
    'corner_taken':"Corners Taken", 
    'touches':"Touches",
    'clearance_off_line':"Clearances Off The Line",
    'penalty_save':"Penalty Saves",
    'total_high_claim':"Total High Claims By Goalkeeper",
    'punches':"Total Punches By Goalkeepers", 
    'season':"Season"                                            
} )

# %%
new_06_07_data
# Out:
#                      Team  Wins  Losses  Goals  Total Yellow Cards  \
# 0       Manchester United  28.0     5.0   83.0                60.0
# 1                 Chelsea  24.0     3.0   64.0                62.0
# 2               Liverpool  20.0    10.0   57.0                44.0
# 3                 Arsenal  19.0     8.0   63.0                59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0                48.0
# ..                    ...   ...     ...    ...                 ...
# 235     Huddersfield Town   9.0    19.0   28.0                62.0
# 236          Swansea City   8.0    21.0   28.0                51.0
# 237           Southampton   7.0    16.0   37.0                63.0
# 238            Stoke City   7.0    19.0   35.0                62.0
# 239  West Bromwich Albion   6.0    19.0   31.0                73.0
#
#      Total Red Cards  Total Scoring Attacks  Scoring On Target Attacks  \
# 0                1.0                  698.0                      256.0
# ...

# %%
new_06_07_data_csv = new_06_07_data.iloc[0:20, :]

# %%
new_06_07_data_csv
# Out:
#                  Team  Wins  Losses  Goals  Total Yellow Cards  \
# 0   Manchester United  28.0     5.0   83.0                60.0
# 1             Chelsea  24.0     3.0   64.0                62.0
# 2           Liverpool  20.0    10.0   57.0                44.0
# 3             Arsenal  19.0     8.0   63.0                59.0
# 4   Tottenham Hotspur  17.0    12.0   57.0                48.0
# 5    Bolton Wanderers  16.0    14.0   47.0                84.0
# 6             Reading  16.0    15.0   52.0                38.0
# 7    Blackburn Rovers  15.0    16.0   52.0                77.0
# 8             Everton  15.0    10.0   52.0                65.0
# 9          Portsmouth  14.0    12.0   45.0                48.0
# 10      Middlesbrough  12.0    16.0   44.0                64.0
# 11    West Ham United  12.0    21.0   35.0                85.0
# 12        Aston Villa  11.0    10.0   43.0                48.0
# 13    Manchester City  11.0    18.0   29.0                59.0
# ...

# %%
new_06_07_data_csv.to_csv('PL_06_07_DF.csv', index=False)

# %%
new_06_07_data
# Out:
#                      Team  Wins  Losses  Goals  Total Yellow Cards  \
# 0       Manchester United  28.0     5.0   83.0                60.0
# 1                 Chelsea  24.0     3.0   64.0                62.0
# 2               Liverpool  20.0    10.0   57.0                44.0
# 3                 Arsenal  19.0     8.0   63.0                59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0                48.0
# ..                    ...   ...     ...    ...                 ...
# 235     Huddersfield Town   9.0    19.0   28.0                62.0
# 236          Swansea City   8.0    21.0   28.0                51.0
# 237           Southampton   7.0    16.0   37.0                63.0
# 238            Stoke City   7.0    19.0   35.0                62.0
# 239  West Bromwich Albion   6.0    19.0   31.0                73.0
#
#      Total Red Cards  Total Scoring Attacks  Scoring On Target Attacks  \
# 0                1.0                  698.0                      256.0
# ...

# %%
new_07_08_data_csv = new_06_07_data.iloc[20:40, :]
new_08_09_data_csv = new_06_07_data.iloc[40:60, :]
new_09_10_data_csv = new_06_07_data.iloc[60:80, :]
new_10_11_data_csv = new_06_07_data.iloc[80:100, :]
new_11_12_data_csv = new_06_07_data.iloc[100:120, :]
new_12_13_data_csv = new_06_07_data.iloc[120:140, :]
new_13_14_data_csv = new_06_07_data.iloc[140:160, :]
new_14_15_data_csv = new_06_07_data.iloc[160:180, :]
new_15_16_data_csv = new_06_07_data.iloc[180:200, :]
new_16_17_data_csv = new_06_07_data.iloc[200:220, :]
new_17_18_data_csv = new_06_07_data.iloc[220:240, :]

# %%
new_07_08_data_csv.to_csv('PL_07_08_DF.csv', index=False)
new_08_09_data_csv.to_csv('PL_08_09_DF.csv', index=False)
new_09_10_data_csv.to_csv('PL_09_10_DF.csv', index=False)
new_10_11_data_csv.to_csv('PL_10_11_DF.csv', index=False)
new_11_12_data_csv.to_csv('PL_11_12_DF.csv', index=False)
new_12_13_data_csv.to_csv('PL_12_13_DF.csv', index=False)
new_13_14_data_csv.to_csv('PL_13_14_DF.csv', index=False)
new_14_15_data_csv.to_csv('PL_14_15_DF.csv', index=False)
new_15_16_data_csv.to_csv('PL_15_16_DF.csv', index=False)
new_16_17_data_csv.to_csv('PL_16_17_DF.csv', index=False)
new_17_18_data_csv.to_csv('PL_17_18_DF.csv', index=False)
